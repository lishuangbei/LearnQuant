# %%
# test MALongPattern
import yfinance as yf
import pandas as pd
import numpy as np

# %%
import MALongPattern as MALP
from Strategy import Strategy

# %%
s = MALP.MALongPattern('AAPL', '2010-1-1', '2019-12-31', 100000, 0.0)

# %%
s.run_strategy()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'sma5', 'sma13', 'sma34', 'sma55', 'sma233', 'close_5_days_ago',
#        'position', 'signal', 'exitPrice'],
#       dtype='object')
# c:\Users\fire_\Python\QuantUnicorn\MALongPattern.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   np.log(data['exitPrice'][sells] / data['Close'].shift(1)[sells])
# c:\Users\fire_\Python\QuantUnicorn\MALongPattern.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'][sells] = 1
# c:\Users\fire_\Python\QuantUnicorn\MALongPattern.py:70: SettingWithCopyWarning:
# ...

# %%
s.results
# Out:
#              Open   High    Low  Close     Volume  Dividends  Stock Splits  \
# Date
# 2010-01-04   6.57   6.60   6.53   6.58  493729600        0.0           0.0
# 2010-01-05   6.60   6.63   6.56   6.59  601904800        0.0           0.0
# 2010-01-06   6.59   6.62   6.48   6.49  552160000        0.0           0.0
# 2010-01-07   6.51   6.52   6.43   6.48  477131200        0.0           0.0
# 2010-01-08   6.47   6.52   6.43   6.52  447610800        0.0           0.0
# ...           ...    ...    ...    ...        ...        ...           ...
# 2019-12-23  69.43  70.35  69.39  70.29   98572000        0.0           0.0
# 2019-12-24  70.46  70.51  70.02  70.35   48478800        0.0           0.0
# 2019-12-26  70.49  71.77  70.46  71.75   93121200        0.0           0.0
# 2019-12-27  72.05  72.75  71.31  71.72  146266000        0.0           0.0
# 2019-12-30  71.64  72.44  70.59  72.15  144114400        0.0           0.0
#
# ...

# %%
s.plot_results()

# %%
import datetime
